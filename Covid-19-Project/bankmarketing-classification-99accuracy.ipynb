# %% [markdown]
# # Importing the Libraries

# %%
# import optuna
import numpy as np
import pandas as pd
import seaborn as sns
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, learning_curve
from sklearn.linear_model import Ridge, LogisticRegression, LassoCV, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score, recall_score, precision_score, f1_score
from sklearn.feature_selection import SelectFromModel, SelectKBest, chi2, RFE, mutual_info_classif as MIC

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv(r"G:\Data Science Eduminds\Projects\Banking\Banking.csv", sep=';')

# %%
print(f"Samples:\t{dataset.shape[0]}\nFeatures:\t{dataset.shape[1]}")
# Out:
# Samples:	45211
# Features:	17

# %% [markdown]
# ### Reordering the columns order as numerical to categorical

# %%
dataset_copy = dataset.copy()
# Separate numerical and categorical columns
numerical_columns = dataset_copy.select_dtypes(include='number').columns.tolist()
categorical_columns = dataset_copy.select_dtypes(exclude='number').columns.tolist()

# Reorder the dataset as starting with numerical columns then categorical
new_order = numerical_columns + categorical_columns
dataset_copy = dataset_copy[new_order]

# %%
dataset_copy.dtypes
# Out:
# age           int64
# balance       int64
# day           int64
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# job          object
# marital      object
# education    object
# default      object
# housing      object
# loan         object
# contact      object
# month        object
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Handling missing values

# %%
# Only categorical features has missing values
categorical_columns = dataset_copy.select_dtypes(exclude='number').columns.tolist()

# Replacing the "unknown" with np.nan
dataset_miss    = dataset_copy.replace('unknown', np.nan).copy()
dataset_no_miss = dataset_miss.fillna(dataset_miss.mode().iloc[0]).copy()

#Check missing values whether correctly removed or not
print(dataset_no_miss[categorical_columns].isna().sum())
# Out:
# job          0
# marital      0
# education    0
# default      0
# housing      0
# loan         0
# contact      0
# month        0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ### Feature Encoding

# %%
dataset_no_encoded = dataset_no_miss.copy()
dataset_encoded    = dataset_no_miss.copy()

# %%
label_encoder = LabelEncoder()

for column in categorical_columns:
    dataset_encoded[column] = label_encoder.fit_transform(dataset_no_encoded[column])

#Check dtypes whether correctly encoded or not
dataset_encoded.dtypes
# Out:
# age          int64
# balance      int64
# day          int64
# duration     int64
# campaign     int64
# pdays        int64
# previous     int64
# job          int32
# marital      int32
# education    int32
# default      int32
# housing      int32
# loan         int32
# contact      int32
# month        int32
# poutcome     int32
# y            int32
# dtype: object

# %% [markdown]
# ## Handling outliers

# %%
dataset_with_outliers = dataset_encoded.copy()

# %%
from scipy.stats import zscore  # Z-score shows better performance than IQR for this particular dataset

z_scores = np.abs(zscore(dataset_with_outliers))
threshold = 3   # threshold=3 gives the suitable option if threshold > 3 then we lost data over %40 
dataset_no_outliers = dataset_with_outliers[(z_scores < threshold).all(axis=1)]

# %%
print(f"Samples with outliers:   \t{dataset_with_outliers.shape[0]}, Columns:\t{dataset_with_outliers.shape[1]}")
print(f"Samples without outliers:\t{dataset_no_outliers.shape[0]}, Columns:\t{dataset_no_outliers.shape[1]}")
print(f"Sample Loss: \t\t\t\t%{((dataset_with_outliers.shape[0] - dataset_no_outliers.shape[0])/dataset_with_outliers.shape[0]) * 100:.4f}")
# Out:
# Samples with outliers:   	45211, Columns:	17
# Samples without outliers:	36027, Columns:	17
# Sample Loss: 				%20.3136

# %% [markdown]
# ## Data Visualization

# %%
import warnings
# Suppress UserWarnings from Seaborn
warnings.filterwarnings("ignore", category=UserWarning)
i = 1
for col in dataset.columns:
    fig, ax = plt.subplots(2,2, figsize=(20, 10))

    # Before outlier removal
    sns.countplot(data=dataset_with_outliers, x=col, palette="deep", hue=col, ax=ax[0,0])
    ax[0,0].set_title(f"Distribution of {col} Column (Before)")
    ax[0, 0].legend_.remove()

    # After outlier removal
    sns.countplot(data=dataset_no_outliers, x=col, palette="deep", hue=col, ax=ax[0,1])
    ax[0,1].set_title(f"Distribution of {col} Column (After)")
    ax[0, 1].legend_.remove()

    # Before outlier removal
    sns.boxplot(data=dataset_with_outliers, x=col, ax=ax[1,0])
    ax[1,0].set_title(f"Boxplot of {col} Column (Before)")

    # After outlier removal
    sns.boxplot(data=dataset_no_outliers, x=col, ax=ax[1,1])
    ax[1,1].set_title(f"Boxplot of {col} Column (After)")

    plt.suptitle(f"Feature {i}: '{col}'", fontsize=32)
    i = i + 1
    plt.show()

# %%
dataset_clean = dataset_no_outliers.copy()

# %% [markdown]
# ## Summary:
# #### Work done:
# * Encoding categorical features, so that we can visualize the distribution, and prepared the feature to use in feature episodes
# * Handle missing value by imputing mode
# * Handle outliers, even though there are still some outliers, we get rid of the most of them. If we tried to removed all of them we lost the %40 of our data, that's why we remained some of them in the feature episodes we'll deak with them using robust scaler
# ###
# #### Feature to be modified:
# * Default:          We'll remove it from the dataset, since it has only one unique value.
# * Duration:         We'll try to get more balance feature distribution.
# * "Campaign":       In 'campaign' column after dealing values there are still some outlier values, we'll deal with them using robust scaler.
# * "pdays:           In 'pdays' column we have the same problem with 'default' feature
# * "emp.var.rate":   We'll try to get more balance feature distribution.
# * "cons.price.idx": We'll try to get more balance feature distribution.
# * "cons.conf.idx":  We'll try to get more balance feature distribution.
# * "euribor3m":      We'll try to get more balance feature distribution.
# * "nr.employed":    We'll try to get more balance feature distribution.

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Feature Extraction:

# %%
def extract_feature_by_thresholds(df,col_name,thresholds):
    flag = 0
    for i in range(len(thresholds) - 1):
        lower_bound = thresholds[i]
        upper_bound = thresholds[i + 1]
        label = i
        if flag == 0:
            mask = (df[col_name] >= lower_bound) & (df[col_name] <= upper_bound) # Hold true or false for values which satisfies the rule or not satisfies
            flag = 1
        else:
            mask = (df[col_name] > lower_bound) & (df[col_name] <= upper_bound)
        df.loc[mask, f'{col_name}_group'] = label # Labeling values which are only the true type in the corresponding columns
    df[f'{col_name}_group'] = df[f'{col_name}_group'].astype(int)

# %%
def print_extract_feature_by_thresholds(df,col_name,thresholds):
    total_samples = len(df)
    flag = 0
    for i in range(len(thresholds) - 1):
        lower_bound = thresholds[i]
        upper_bound = thresholds[i + 1]
        if flag == 0:
            mask = (df[col_name] >= lower_bound) & (df[col_name] <= upper_bound)
            flag = 1
        else:
            mask = (df[col_name] > lower_bound) & (df[col_name] <= upper_bound)
        count = df.loc[mask].shape[0]
        percentage = (count / total_samples)
        rounded_percentage = round(percentage, 4)
        print(f"({lower_bound}_{upper_bound}] = {rounded_percentage}, samples:{count}")

# %%
def generate_threshold(df,col_name,increment_range):
    start = df[col_name].min() - (df[col_name].min())%increment_range
    end   = df[col_name].max() - (df[col_name].max())%increment_range + increment_range
    
    thresholds = []
    threshold = start
    while threshold <= end:
        thresholds.append(threshold)
        threshold += increment_range
    return thresholds

# %%
def visualize_extracted_columns_distribution(df_before,df_after,col_name):
    fig, ax = plt.subplots(1,2, figsize=(20, 5))

    # Before extraction feature
    sns.countplot(data=df_before, x=col_name, palette="Set2", hue=col_name,  ax=ax[0])
    ax[0].set_title(f"Distribution of {col_name} Column (Before)")
    ax[0].legend_.remove()
    
    # After extraction feature
    sns.countplot(data=df_after, x=col_name+'_group',palette="Set2", hue=col_name+'_group', ax=ax[1])
    ax[1].set_title(f"Distribution of {col_name+'_group'} Column (After)")
    ax[1].legend_.remove()
    
    plt.show()

# %%
dataset_no_modified = dataset_clean.copy()
dataset_modified    = dataset_clean.copy()

# %% [markdown]
# ##### 1-) "Default"

# %%
dataset_modified.drop(['default'], axis=1, inplace=True)

# %% [markdown]
# ##### 2-) "duration"

# %%
duration_threshold = generate_threshold(dataset_modified,'duration',100)
print(f"Duration threshold:\t{duration_threshold}")
print_extract_feature_by_thresholds(dataset_modified,'duration',duration_threshold)
# Out:
# Duration threshold:	[0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100]
# (0_100] = 0.2352, samples:8475
# (100_200] = 0.3236, samples:11658
# (200_300] = 0.1824, samples:6571
# (300_400] = 0.1003, samples:3615
# (400_500] = 0.0568, samples:2047
# (500_600] = 0.036, samples:1296
# (600_700] = 0.0263, samples:946
# (700_800] = 0.0172, samples:618
# (800_900] = 0.0117, samples:422
# (900_1000] = 0.0085, samples:306
# (1000_1100] = 0.002, samples:73

# %%
extract_feature_by_thresholds(dataset_modified,'duration',duration_threshold)
visualize_extracted_columns_distribution(dataset_no_modified,dataset_modified,'duration')

# %% [markdown]
# ##### 3-) "pdays"

# %%
dataset_modified.drop(['pdays'],axis=1, inplace=True)

# %% [markdown]
# ##### 4-) "emp.var.rate"

# %%
emp_rate_threshold = generate_threshold(dataset_modified,'emp.var.rate',5)
print(f"emp.var.rate threshold:\t{emp_rate_threshold}")
print_extract_feature_by_thresholds(dataset_modified,'emp.var.rate',emp_rate_threshold)
# Out:
# emp.var.rate threshold:	[-5.0, 0.0, 5.0]
#
# (-5.0_0.0] = 0.3924, samples:14640
#
# (0.0_5.0] = 0.6076, samples:22671

# %%
extract_feature_by_thresholds(dataset_modified,'emp.var.rate',emp_rate_threshold)
visualize_extracted_columns_distribution(dataset_no_modified,dataset_modified,'emp.var.rate')

# %% [markdown]
# ##### 5-) "cons.price.idx"

# %%
cons_price_threshold = generate_threshold(dataset_modified,'cons.price.idx',1)
print(f"cons.price.idx threshold:\t{cons_price_threshold}")
print_extract_feature_by_thresholds(dataset_modified,'cons.price.idx',cons_price_threshold)
# Out:
# cons.price.idx threshold:	[92.0, 93.0, 94.0, 95.0]
#
# (92.0_93.0] = 0.2084, samples:7776
#
# (93.0_94.0] = 0.6642, samples:24781
#
# (94.0_95.0] = 0.1274, samples:4754

# %%
extract_feature_by_thresholds(dataset_modified,'cons.price.idx',cons_price_threshold)
visualize_extracted_columns_distribution(dataset_no_modified,dataset_modified,'cons.price.idx')

# %% [markdown]
# ##### 6-) "cons.conf.idx"

# %%
cons_conf_threshold = generate_threshold(dataset_modified,'cons.conf.idx',20)
print(f"cons.conf.idx threshold:\t{cons_conf_threshold}")
print_extract_feature_by_thresholds(dataset_modified,'cons.conf.idx',cons_conf_threshold)
# Out:
# cons.conf.idx threshold:	[-60.0, -40.0, -20.0]
#
# (-60.0_-40.0] = 0.6104, samples:22775
#
# (-40.0_-20.0] = 0.3896, samples:14536

# %%
extract_feature_by_thresholds(dataset_modified,'cons.conf.idx',cons_conf_threshold)
visualize_extracted_columns_distribution(dataset_no_modified,dataset_modified,'cons.conf.idx')

# %% [markdown]
# ##### 7-) "euribor3m"

# %%
euribor_threshold = generate_threshold(dataset_modified,'euribor3m',0.125)
print(f"euribor3m threshold:\t{euribor_threshold}")
print_extract_feature_by_thresholds(dataset_modified,'euribor3m',euribor_threshold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 euribor_threshold = generate_threshold(dataset_modified,'euribor3m',0.125)
#       2 print(f"euribor3m threshold:\t{euribor_threshold}")
#       3 print_extract_feature_by_thresholds(dataset_modified,'euribor3m',euribor_threshold)
#
# NameError: name 'dataset_modified' is not defined

# %%
extract_feature_by_thresholds(dataset_modified,'euribor3m',euribor_threshold)
visualize_extracted_columns_distribution(dataset_no_modified,dataset_modified,'euribor3m')

# %% [markdown]
# ##### 8-) "nr.employed"

# %%
employed_threshold = generate_threshold(dataset_modified,'nr.employed',50)
print(f"nr.employed threshold:\t{employed_threshold}")
print_extract_feature_by_thresholds(dataset_modified,'nr.employed',employed_threshold)
# Out:
# nr.employed threshold:	[4950.0, 5000.0, 5050.0, 5100.0, 5150.0, 5200.0, 5250.0]
#
# (4950.0_5000.0] = 0.0187, samples:697
#
# (5000.0_5050.0] = 0.0306, samples:1142
#
# (5050.0_5100.0] = 0.2471, samples:9221
#
# (5100.0_5150.0] = 0.0, samples:0
#
# (5150.0_5200.0] = 0.2962, samples:11052
#
# (5200.0_5250.0] = 0.4074, samples:15199

# %%
extract_feature_by_thresholds(dataset_modified,'nr.employed',employed_threshold)
visualize_extracted_columns_distribution(dataset_no_modified,dataset_modified,'nr.employed')

# %%
dataset_modified.dtypes
# Out:
# age          int64
# balance      int64
# day          int64
# duration     int64
# campaign     int64
# previous     int64
# job          int32
# marital      int32
# education    int32
# housing      int32
# loan         int32
# contact      int32
# month        int32
# poutcome     int32
# y            int32
# dtype: object

# %% [markdown]
# ### Summary:
# #### Work done:
# * Extracted new features: {duration_group, emp.var.rate_group, cons.price.idx_group, cons.conf.idx_group, euribor3m_group, nr.employed_group}
# * Removed features: {default,pdays}

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Feature Reduction & Selection:

# %%
dataset_no_selection = dataset_modified.copy()

# %%
fig= plt.figure(figsize=(16,16))
corr = dataset_no_selection.corr()
mask = np.triu(dataset_no_selection.corr())

axes = fig.add_axes([0, 0, 1, 1])
sns.heatmap(corr, annot=True, mask=mask, square=True,fmt='.2g',vmin=-1, vmax=1, center= 0, cmap='viridis',
            linecolor='white', cbar_kws= {'orientation': 'vertical'}, ax=axes)
# Out:
# <Axes: >

# %%
# Remove the one of the high correlated features
# dataset_selected = dataset_no_selection.drop(['duration','poutcome','emp.var.rate','cons.price.idx','cons.conf.idx','euribor3m','nr.employed','euribor3m_group','emp.var.rate_group'], axis=1).copy()
dataset_selected = dataset_no_selection

# %%
dataset_selected.columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'previous', 'job',
#        'marital', 'education', 'housing', 'loan', 'contact', 'month',
#        'poutcome', 'y'],
#       dtype='object')

# %%
fig= plt.figure(figsize=(16,16))
corr = dataset_selected.corr()
mask = np.triu(dataset_selected.corr())

axes = fig.add_axes([0, 0, 1, 1])
sns.heatmap(corr, annot=True, mask=mask, square=True,fmt='.2g',vmin=-1, vmax=1, center= 0, cmap='viridis',
            linecolor='white', cbar_kws= {'orientation': 'vertical'}, ax=axes)
# Out:
# <Axes: >

# %%
print(f"Samples in original clean dataset:\t{dataset_clean.shape[0]}, Features:\t{dataset_clean.shape[1]}")
print(f"Samples without selection:\t\t\t{dataset_no_selection.shape[0]}, Features:\t{dataset_no_selection.shape[1]}")
print(f"Samples with selection:\t\t\t\t{dataset_selected.shape[0]}, Features:\t{dataset_selected.shape[1]}")
# Out:
# Samples in original clean dataset:	36027, Features:	17
# Samples without selection:			36027, Features:	15
# Samples with selection:				36027, Features:	15

# %% [markdown]
# ### Feature Sampling:

# %%
X = dataset_selected.drop(['y'], axis=1).copy()
y = dataset_selected['y'].copy()

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
oversampling = RandomOverSampler()
X_oversampled, y_oversampled = oversampling.fit_resample(X, y)

# Before feature sampling
counter_before = Counter(y)
# After feature sampling
counter_after = Counter(y_oversampled)

print(f"Before oversampling:{counter_before}")
print(f"After oversampling:{counter_after}")
print(f"Feature sampling percentage: %{((y_oversampled.shape[0] - y.shape[0])/y.shape[0])*100:.2f}")
# Out:
# Before oversampling:Counter({0: 32976, 1: 3051})
# After oversampling:Counter({0: 32976, 1: 32976})
# Feature sampling percentage: %83.06
# C:\Anaconda\Lib\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %%
# Original dataset
counts_original = dataset_selected['y'].value_counts()
labels_original = ['no' if x == 0 else 'yes' for x in counts_original.index]

# Oversampled dataset
counts_oversampled = y_oversampled.value_counts()
labels_oversampled = ['no' if x == 0 else 'yes' for x in counts_oversampled.index]

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Plot for original dataset
axs[0].pie(counts_original, labels=labels_original, autopct='%1.1f%%', startangle=0, colors=sns.color_palette("gist_stern"))
axs[0].set_title("Original Dataset", fontsize=15)
axs[0].axis('equal')  # Make the pie chart circular

# Plot for oversampled dataset
axs[1].pie(counts_oversampled, labels=labels_oversampled, autopct='%1.1f%%', startangle=0, colors=sns.color_palette("gist_stern"))
axs[1].set_title("Oversampled Dataset", fontsize=15)
axs[1].axis('equal')  # Make the pie chart circular

plt.suptitle("Pie Plots for Feature Sampling", fontsize=18, y=1.05)
plt.show()

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import RobustScaler
scaler_robust = RobustScaler()  # Since we have outliers that we couldn't remove we use robust scaler to resist outliers
X_robust = scaler_robust.fit_transform(X_oversampled)
X_non_negative = X_robust - X_robust.min() + 1e-10

# %% [markdown]
# ### Feature Selection:

# %%
# Prepare dataset for RFE (Recursive Feature Elimination)
def func_RFE_X_rfe(param_X,param_y):
    model = RandomForestClassifier()
    rfe = RFE(model, step = 4)
    fit = rfe.fit(param_X,param_y)
    selected_features = fit.support_
    X_rfe = param_X[:, selected_features]
    return X_rfe

# %%
# Prepare dataset for SelectKBest (score_func=chi2)
def func_SelectKBest_X_chi2(param_X,param_y):
    test = SelectKBest(score_func=chi2, k=23)
    fit = test.fit(param_X,param_y)
    X_chi2 = fit.transform(param_X)
    return X_chi2

# %%
# Prepare dataset for Ridge
def func_Ridge_X_ridge(param_X,param_y):
    ridge = Ridge(alpha=1.0)
    ridge.fit(param_X,param_y)
    best_alpha = ridge.alpha
    ridge_model = Ridge(alpha=best_alpha)
    ridge_model.fit(param_X,param_y)
    selector = SelectFromModel(ridge_model)
    X_ridge = selector.transform(param_X)
    return X_ridge

# %%
# Prepare dataset for MIC (mutual_info_classification)
def func_MIC_X_mic(param_X,param_y):
    mi_scores = MIC(param_X,param_y)
    mi_score_selected_index = np.where(mi_scores <0.2)[0]
    X_mic = param_X[:,mi_score_selected_index]
    return X_mic

# %%
def func_Lasso_X(param_X, param_y):
    lasso = LassoCV(cv=10)
    lasso.fit(param_X, param_y)
    best_alpha = lasso.alpha_

    selector = SelectFromModel(Lasso(alpha=best_alpha), threshold='median')
    X_lasso = selector.fit_transform(param_X, param_y)

    return X_lasso

# %%
def print_scores(accuracy_score, recall_score, precision_score, f1_score, model_name):
    print(f"accuracy_{model_name}:{accuracy_score:10.4f}\t"
          f"recall {model_name}:{recall_score:10.4f}\t"
          f"precision {model_name}:{precision_score:10.4f}\t"
          f"f1_score_{model_name}:{f1_score:10.4f}")

# %%
def predict_scores(model, x_test, y_test):
    y_predict       = model.predict(x_test)
    score_accuracy  = accuracy_score(y_test, y_predict)
    score_recall    = recall_score(y_test,y_predict)
    score_precision = precision_score(y_test,y_predict)
    f1_scr          = f1_score(y_test, y_predict)
    return score_accuracy,score_recall,score_precision, f1_scr

# %%
def func_Calculate_Model_Scores(param_x,param_y, X_chi2, X_rfe, X_ridge, X_mic, X_lasso):
    # Split the data into training and testing sets
    
    X_train, X_test, y_train, y_test                     = train_test_split(param_x,param_y, random_state=0, stratify=param_y)
    X_train_chi2, X_test_chi2, y_train_chi2, y_test_chi2 = train_test_split(X_chi2, param_y, random_state=0, stratify=param_y)
    X_train_RFE, X_test_RFE, y_train_RFE, y_test_RFE     = train_test_split(X_rfe, param_y, random_state=0, stratify=param_y)
    X_train_Ridge, X_test_Ridge, y_train_Ridge, y_test_Ridge = train_test_split(X_ridge, param_y, random_state=0, stratify=param_y)
    X_train_MIC, X_test_MIC, y_train_MIC, y_test_MIC     = train_test_split(X_mic, param_y, random_state=0, stratify=param_y)
    X_train_Lasso, X_test_Lasso, y_train_Lasso, y_test_Lasso = train_test_split(X_lasso, param_y, random_state=0, stratify=param_y)
    RFC = RandomForestClassifier()

    # Compare results with Random Forest Classifier
    model_default = RFC.fit(X_train,y_train)
    score_default, recall_score_default, precision_score_default, f1_score_default = predict_scores(model_default,X_test,y_test) 

    model_MIC = RFC.fit(X_train_MIC,y_train_MIC)
    score_MIC, recall_score_MIC, precision_score_MIC, f1_score_MIC = predict_scores(model_MIC,X_test_MIC,y_test_MIC)

    model_chi2 = RFC.fit(X_train_chi2,y_train_chi2)
    score_chi2, recall_score_chi2, precision_score_chi2, f1_score_chi2 = predict_scores(model_chi2,X_test_chi2,y_test_chi2)

    model_RFE = RFC.fit(X_train_RFE,y_train_RFE)
    score_rfe, recall_score_rfe, precision_score_rfe, f1_score_rfe = predict_scores(model_RFE,X_test_RFE,y_test_RFE)

    model_Ridge = RFC.fit(X_train_Ridge,y_train_Ridge)
    score_ridge, recall_score_ridge, precision_score_ridge, f1_score_ridge = predict_scores(model_Ridge,X_test_Ridge,y_test_Ridge)

    model_Lasso = RFC.fit(X_train_Lasso,y_train_Lasso)
    score_lasso, recall_score_lasso, precision_score_lasso, f1_score_lasso = predict_scores(model_Lasso,X_test_Lasso,y_test_Lasso)
    
    #---------------------------------------------------------------------------------
    model_names = ['Default','CHI2','RFE','Ridge','MIC','Lasso']
    scores = [score_default ,score_chi2 ,score_rfe ,score_ridge ,score_MIC ,score_lasso]
    recalls = [recall_score_default ,recall_score_chi2 ,recall_score_rfe ,recall_score_ridge ,recall_score_MIC ,recall_score_lasso]
    precisions = [precision_score_default,precision_score_chi2,precision_score_rfe,precision_score_ridge,precision_score_MIC,precision_score_lasso]
    f1_scores = [f1_score_default,f1_score_chi2,f1_score_rfe,f1_score_ridge,f1_score_MIC,f1_score_lasso]

    scores_df = pd.DataFrame({
        "Model": model_names,
        "Score": scores,
        "Recall": recalls,
        "Precision": precisions,
        "F1 Score": f1_scores
    })
    
    return  scores_df

# %%
print("Scores for robust scaler:")
x_chi2 = func_SelectKBest_X_chi2(X_non_negative,y_oversampled)
x_rfe = func_RFE_X_rfe(X_non_negative,y_oversampled)
x_ridge = func_Ridge_X_ridge(X_non_negative,y_oversampled)
x_mic = func_MIC_X_mic(X_non_negative,y_oversampled)
x_lasso = func_Lasso_X(X_non_negative,y_oversampled)

df_featureSelection  = func_Calculate_Model_Scores(X_non_negative, y_oversampled, x_chi2, x_rfe, x_ridge, x_mic, x_lasso)
df_featureSelection
# Out:
# Scores for robust scaler:
#      Model     Score    Recall  Precision  F1 Score
# 0  Default  0.981623  1.000000   0.964549  0.981955
# 1     CHI2  0.981077  1.000000   0.963534  0.981429
# 2      RFE  0.977620  1.000000   0.957158  0.978110
# 3    Ridge  0.808164  0.852984   0.782812  0.816393
# 4      MIC  0.979925  1.000000   0.961399  0.980320
# 5    Lasso  0.943171  0.995876   0.900911  0.946016

# %% [markdown]
# ## Implementing Elbow

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt


pca = PCA()
pca.fit(x_chi2)

explained_var = pca.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)

plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_var) + 1), cumulative_var, marker='o', linestyle='--')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')

# Calculate the rate of change in explained variance
diff = np.diff(cumulative_var)
change_point = np.where(diff == np.min(diff))[0][0] + 1

plt.axvline(x=change_point, color='orange', linestyle='--', label=f'Change at {change_point} components')
plt.text(change_point + 0.5, cumulative_var[change_point - 1] - 0.05, f'({change_point}, {cumulative_var[change_point - 1]:.2f})', color='red')

plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=change_point) 
X_pca = pca.fit_transform(x_chi2)

X_train, X_test, y_train, y_test = train_test_split(X_pca, y_oversampled, test_size=0.2, random_state=42)

model_rfc_pca = RandomForestClassifier()
model_rfc_pca.fit(X_train, y_train)

# Make predictions
y_pred = model_rfc_pca.predict(X_test)

score_default, recall_score_default, precision_score_default, f1_score_default = predict_scores(model_rfc_pca,X_test,y_test)

print("Scores for PCA with RandomForest:")
print("Accuracy: {:.4f}".format(score_default))
print("Recall: {:.4f}".format(recall_score_default))
print("Precision: {:.4f}".format(precision_score_default))
print("F1 Score: {:.4f}".format(f1_score_default))
# Out:
# Scores for PCA with RandomForest:
# Accuracy: 0.9826
# Recall: 1.0000
# Precision: 0.9664
# F1 Score: 0.9829

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
X_train, X_test, y_train, y_test   = train_test_split(X_pca,y_oversampled, random_state=42)

# %% [markdown]
# # Feature Scaling

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # ML Algorithms Implementation:

# %%
def plot_confusion_matrices(X_test, y_test, models, model_names):
    num_models = len(models)

    # Create subplots based on the number of models
    fig, axes = plt.subplots(1, num_models, figsize=(6 * num_models, 5))

    for i, (model, model_name) in enumerate(zip(models, model_names)):
        # Generate confusion matrix
        y_pred = model.predict(X_test)
        cm = confusion_matrix(y_test, y_pred)

        # Create a custom colormap for better readability
        cmap = sns.diverging_palette(250, 10, as_cmap=True)

        # Create a heatmap with customized colors and annotations
        ax = axes[i] if num_models > 1 else axes
        sns.heatmap(cm, annot=True, cmap=cmap, fmt='g', cbar=False, ax=ax)

        # Set labels, title, and layout
        ax.set_title(f'Confusion Matrix of {model_name}', fontsize=16)
        ax.set_xlabel('Predicted', fontsize=8)
        ax.set_ylabel('Actual', fontsize=8)
        ax.set_xticks([0.5, 1.5])
        ax.set_xticklabels(['Negative', 'Positive'])
        ax.set_yticks([0.5, 1.5])
        ax.set_yticklabels(['Negative', 'Positive'])
        ax.tick_params(axis='both', which='both', length=0)  # Remove ticks

    plt.tight_layout()
    plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

def draw_AUC_graph(train_X, test_X, train_y, test_y, models, model_names):
    num_models = len(models)

    # Create subplots with the number of rows determined by the number of models
    fig, axes = plt.subplots(1, ncols=num_models, figsize=(6*num_models,5))

    for i in range(num_models):
        model = models[i]
        model_name = model_names[i]

        # Get predicted probabilities for the positive class for both train and test sets
        y_train_probs = model.predict_proba(train_X)[:, 1]
        y_test_probs = model.predict_proba(test_X)[:, 1]

        # Compute ROC curve and ROC AUC for both train and test sets
        fpr_train, tpr_train, _ = roc_curve(train_y, y_train_probs)
        fpr_test, tpr_test, _ = roc_curve(test_y, y_test_probs)

        roc_auc_train = roc_auc_score(train_y, y_train_probs)
        roc_auc_test = roc_auc_score(test_y, y_test_probs)

        # Plot ROC curves for both train and test sets, display AUC values as labels
        if num_models > 1:
            ax = axes[i]
        else:
            ax = axes

        ax.plot(fpr_train, tpr_train, label=f'Train ROC Curve (AUC = {roc_auc_train:.2f})')
        ax.plot(fpr_test, tpr_test, label=f'Test ROC Curve (AUC = {roc_auc_test:.2f})')
        ax.plot([0, 1], [0, 1], 'r--', label='Random Guessing')
        ax.set_xlabel('False Positive Rate (FPR)')
        ax.set_ylabel('True Positive Rate (TPR)')
        ax.set_title(f'Receiver Operating Characteristic (ROC) Curve for {model_name}')
        ax.legend()

        print(f"{model_name} - Train AUC: {roc_auc_train:.4f}")
        print(f"{model_name} - Test AUC: {roc_auc_test:.4f}")

    plt.tight_layout()
    plt.show()

# %%
def bias_variance(model, X_train, y_train):
    train_sizes, train_scores, test_scores = learning_curve(model, X_train, y_train, train_sizes=np.linspace(0.1, 1.0, 10), cv=3)

    # Calculate the mean for training and test scores
    train_mean = np.mean(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)

    bias = 1 - train_mean
    variance = test_mean - train_mean

    # Plot Bias-Variance Tradeoff
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(train_sizes, bias, 'o-', color="blue", label="Bias")
    ax.plot(train_sizes, variance, 'o-', color="orange", label="Variance")
    ax.set_xlabel("Training examples")
    ax.set_ylabel("Error")
    ax.set_title("Bias-Variance Tradeoff for the dataset")
    ax.legend(loc="best")
    ax.grid()
    ax.set_ylim(bottom=-1, top=1)
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve

def visualize_fitting_scores(models, model_names, X_train, y_train, X_test, y_test):
    num_models = len(models)

    fig, axes = plt.subplots(nrows=1, ncols=num_models, figsize=(5 * num_models, 6))

    for i in range(num_models):
        model = models[i]
        model_name = model_names[i]

        train_sizes, train_scores, test_scores = learning_curve(model, X_train, y_train, train_sizes=np.linspace(0.1, 1.0, 10), cv=3)

        # Calculate the mean for training and test scores
        train_mean = np.mean(train_scores, axis=1)
        train_std = np.std(train_scores, axis=1)
        test_mean = np.mean(test_scores, axis=1)
        test_std = np.std(test_scores, axis=1)
        
        # Plot Learning Curve
        axes[i].fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.1, color="b")
        axes[i].fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.1, color="r")
        axes[i].plot(train_sizes, train_mean, 'o-', color="blue", label="Training score")
        axes[i].plot(train_sizes, test_mean, 'o-', color="red", label="Cross-validation score")

        # Calculate test score separately
        test_sizes = np.array([(j + 1) * len(X_train) // 10 for j in range(10)])
        test_score = [model.score(X_test[:size], y_test[:size]) for size in test_sizes]
        axes[i].plot(test_sizes, test_score, 'o-', color="orange", label="Test score")

        axes[i].set_xlabel("Training examples")
        axes[i].set_ylabel("Score")
        axes[i].set_title(f"Learning Curve with Training, Cross-validation, and Test Scores for {model_name}")
        axes[i].legend(loc="best")
        axes[i].grid()

    plt.tight_layout()
    plt.show()

# %%
def ml_algorithms(X_train,y_train):

    # Initialize individual classifiers
    dtc = DecisionTreeClassifier()
    knn = KNeighborsClassifier()
    logistic = LogisticRegression(max_iter=1000)
    rfc = RandomForestClassifier()
    gb = GradientBoostingClassifier()

    # Fit individual classifiers
    dtc.fit(X_train, y_train)
    knn.fit(X_train, y_train)
    logistic.fit(X_train, y_train)
    rfc.fit(X_train, y_train)
    gb.fit(X_train, y_train)
    
    return dtc, knn, logistic, rfc, gb

# %%
# !pip install xgboost
# !pip install optuna
# Out:
# ^C
# Requirement already satisfied: xgboost in c:\anaconda\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\anaconda\lib\site-packages (from xgboost) (1.13.1)
# Collecting optuna
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\anaconda\lib\site-packages (from optuna) (2.0.34)
# Requirement already satisfied: tqdm in c:\anaconda\lib\site-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in c:\anaconda\lib\site-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.12 (from alembic>=1.5.0->optuna)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\anaconda\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\anaconda\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
# Downloading alembic-1.15.1-py3-none-any.whl (231 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
# Installing collected packages: typing-extensions, Mako, colorlog, alembic, optuna
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
# Successfully installed Mako-1.3.9 alembic-1.15.1 colorlog-6.9.0 optuna-4.2.1 typing-extensions-4.12.2

# %%
def ensemble_models(X_train,y_train,estimators):
    
    xgboost = xgb.XGBClassifier()
    voting = VotingClassifier(estimators=estimators, voting='soft')
    stacking = StackingClassifier(estimators=estimators)

    xgboost.fit(X_train,y_train)
    voting.fit(X_train,y_train)
    stacking.fit(X_train,y_train)
    
    return  xgboost, voting, stacking

# %% [markdown]
# # Training the Classification models on the Training set

# %% [markdown]
# ## ML Models

# %%
model_dtc, model_knn, model_lr, model_rfc, model_gb= ml_algorithms(X_train=X_train,y_train=y_train)

# %% [markdown]
# ## Ensemble Models

# %%
estimators = [('dtc',model_dtc),('knn',model_knn),('logistic',model_lr),('rfc',model_rfc),('gb', model_gb)]
model_xgb, model_voting, model_stacking = ensemble_models(X_train=X_train,y_train=y_train,estimators=estimators)

# %% [markdown]
# # Hyper tuning of ML and ensemble models

# %% [markdown]
# ## RFC

# %%
param_grid = {
    'n_estimators': [50, 100],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [1,5],
    'random_state': [0,42]
}

# Create GridSearchCV
grid_search = GridSearchCV(estimator=model_rfc, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2, error_score='raise')

# Perform grid search on training data
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
print(best_params)
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# KeyboardInterrupt

# %%
best_model_rfc = RandomForestClassifier(**best_params)
best_model_rfc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 best_model_rfc = RandomForestClassifier(**best_params)
#       2 best_model_rfc.fit(X_train, y_train)
#
# NameError: name 'best_params' is not defined

# %% [markdown]
# ## XGB

# %%
# taking from https://optuna.readthedocs.io/en/stable/
def objective(trial):
    param_grid = {
        'objective': 'binary:logistic',
        'eval_metric': 'error',
        'booster': 'gbtree',
        'verbosity': 0,
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10)
    }

    xgb_model = xgb.XGBClassifier(**param_grid)
    xgb_model.fit(X_train, y_train)

    predictions = xgb_model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    return 1.0 - accuracy 

# Create an Optuna study and optimize the objective function
study = optuna.create_study(direction='minimize')  # Minimize the error (1 - accuracy)
study.optimize(objective, n_trials=100)
print(best_params)
# Out:
# [I 2024-01-23 14:48:14,867] A new study created in memory with name: no-name-ce9dc8ff-2619-4120-8e9d-695f36e5e79e
#
# [I 2024-01-23 14:48:15,731] Trial 0 finished with value: 0.07011413929652921 and parameters: {'n_estimators': 564, 'max_depth': 5, 'learning_rate': 0.047232008882187315, 'subsample': 0.8773537305038168, 'colsample_bytree': 0.7828008775251489, 'gamma': 0.8883889399384651, 'min_child_weight': 7}. Best is trial 0 with value: 0.07011413929652921.
#
# [I 2024-01-23 14:48:16,501] Trial 1 finished with value: 0.047111576985790826 and parameters: {'n_estimators': 738, 'max_depth': 4, 'learning_rate': 0.18583155638293505, 'subsample': 0.9864939932239496, 'colsample_bytree': 0.5113885586911832, 'gamma': 0.5506572268922953, 'min_child_weight': 3}. Best is trial 1 with value: 0.047111576985790826.
#
# [I 2024-01-23 14:48:17,434] Trial 2 finished with value: 0.0369788027020731 and parameters: {'n_estimators': 241, 'max_depth': 9, 'learning_rate': 0.06558563888426838, 'subsample': 0.8731533571714615, 'colsample_bytree': 0.5612453712036202, 'gamma': 0.10888583703311105, 'min_child_weight': 3}. Best is trial 2 with value: 0.0369788027020731.
#
# [I 2024-01-23 14:48:18,765] Trial 3 finished with value: 0.0302818541812252 and parameters: {'n_estimators': 978, 'max_depth': 5, 'learning_rate': 0.2225374306550589, 'subsample': 0.612462611801196, 'colsample_bytree': 0.5869417363016977, 'gamma': 0.05250261526665645, 'min_child_weight': 2}. Best is trial 3 with value: 0.0302818541812252.
#
# [I 2024-01-23 14:48:23,571] Trial 4 finished with value: 0.037502911716748244 and parameters: {'n_estimators': 701, 'max_depth': 10, 'learning_rate': 0.012251960018613452, 'subsample': 0.7436448753153219, 'colsample_bytree': 0.7520847586220225, 'gamma': 0.33626340068836635, 'min_child_weight': 1}. Best is trial 3 with value: 0.0302818541812252.
#
# [I 2024-01-23 14:48:23,744] Trial 5 finished with value: 0.10406475658047987 and parameters: {'n_estimators': 123, 'max_depth': 3, 'learning_rate': 0.27115857306877583, 'subsample': 0.609391846219923, 'colsample_bytree': 0.588880604950147, 'gamma': 0.13916986150066546, 'min_child_weight': 6}. Best is trial 3 with value: 0.0302818541812252.
#
# [I 2024-01-23 14:48:24,677] Trial 6 finished with value: 0.03307710225949223 and parameters: {'n_estimators': 600, 'max_depth': 6, 'learning_rate': 0.20094306584015806, 'subsample': 0.7099954985653065, 'colsample_bytree': 0.8495652799585236, 'gamma': 0.8045659427071558, 'min_child_weight': 6}. Best is trial 3 with value: 0.0302818541812252.
#
# [I 2024-01-23 14:48:25,354] Trial 7 finished with value: 0.03680409969718146 and parameters: {'n_estimators': 453, 'max_depth': 5, 'learning_rate': 0.27591283475705447, 'subsample': 0.829107038938179, 'colsample_bytree': 0.8272725093025151, 'gamma': 0.21896745755994085, 'min_child_weight': 10}. Best is trial 3 with value: 0.0302818541812252.
#
# [I 2024-01-23 14:48:25,997] Trial 8 finished with value: 0.03569764733286751 and parameters: {'n_estimators': 431, 'max_depth': 5, 'learning_rate': 0.2753391857792573, 'subsample': 0.7228031697676194, 'colsample_bytree': 0.7261491257652499, 'gamma': 0.951384458316876, 'min_child_weight': 1}. Best is trial 3 with value: 0.0302818541812252.
#
# [I 2024-01-23 14:48:27,029] Trial 9 finished with value: 0.054973212205916555 and parameters: {'n_estimators': 543, 'max_depth': 6, 'learning_rate': 0.0393047298599118, 'subsample': 0.6946948386817853, 'colsample_bytree': 0.8950865539174204, 'gamma': 0.031082951198189934, 'min_child_weight': 3}. Best is trial 3 with value: 0.0302818541812252.
#
# [I 2024-01-23 14:48:29,089] Trial 10 finished with value: 0.0302818541812252 and parameters: {'n_estimators': 990, 'max_depth': 8, 'learning_rate': 0.11992180996618397, 'subsample': 0.5115201193322203, 'colsample_bytree': 0.9934981101051696, 'gamma': 0.5262010248842085, 'min_child_weight': 9}. Best is trial 3 with value: 0.0302818541812252.
#
# [I 2024-01-23 14:48:31,120] Trial 11 finished with value: 0.030223619846261318 and parameters: {'n_estimators': 979, 'max_depth': 8, 'learning_rate': 0.11163516589949729, 'subsample': 0.5516250502849421, 'colsample_bytree': 0.9902442056479813, 'gamma': 0.5636894974213952, 'min_child_weight': 10}. Best is trial 11 with value: 0.030223619846261318.
#
# [I 2024-01-23 14:48:32,866] Trial 12 finished with value: 0.030223619846261318 and parameters: {'n_estimators': 980, 'max_depth': 8, 'learning_rate': 0.12544648129779756, 'subsample': 0.5072021652744029, 'colsample_bytree': 0.6616909255809773, 'gamma': 0.6801304493818381, 'min_child_weight': 8}. Best is trial 11 with value: 0.030223619846261318.
#
# [I 2024-01-23 14:48:34,492] Trial 13 finished with value: 0.030048916841369677 and parameters: {'n_estimators': 851, 'max_depth': 8, 'learning_rate': 0.11969916895368973, 'subsample': 0.519668066911476, 'colsample_bytree': 0.6799490387265715, 'gamma': 0.6809012522576363, 'min_child_weight': 8}. Best is trial 13 with value: 0.030048916841369677.
#
# [I 2024-01-23 14:48:36,213] Trial 14 finished with value: 0.03138830654553926 and parameters: {'n_estimators': 838, 'max_depth': 8, 'learning_rate': 0.10969923862896587, 'subsample': 0.5969300367905509, 'colsample_bytree': 0.9959161140225427, 'gamma': 0.6861688928610251, 'min_child_weight': 10}. Best is trial 13 with value: 0.030048916841369677.
#
# [I 2024-01-23 14:48:37,820] Trial 15 finished with value: 0.0302818541812252 and parameters: {'n_estimators': 850, 'max_depth': 7, 'learning_rate': 0.1609952691549218, 'subsample': 0.579374922168312, 'colsample_bytree': 0.6787641362089326, 'gamma': 0.3726125586212254, 'min_child_weight': 8}. Best is trial 13 with value: 0.030048916841369677.
#
# [I 2024-01-23 14:48:39,849] Trial 16 finished with value: 0.03179594689028653 and parameters: {'n_estimators': 841, 'max_depth': 10, 'learning_rate': 0.08376462860701007, 'subsample': 0.5475019461761793, 'colsample_bytree': 0.9158748605275424, 'gamma': 0.6659557361968875, 'min_child_weight': 9}. Best is trial 13 with value: 0.030048916841369677.
#
# [I 2024-01-23 14:48:41,216] Trial 17 finished with value: 0.029815979501514045 and parameters: {'n_estimators': 740, 'max_depth': 7, 'learning_rate': 0.15128424194454468, 'subsample': 0.6481282904939378, 'colsample_bytree': 0.652433347999795, 'gamma': 0.43857399987233, 'min_child_weight': 5}. Best is trial 17 with value: 0.029815979501514045.
#
# [I 2024-01-23 14:48:42,625] Trial 18 finished with value: 0.029757745166550165 and parameters: {'n_estimators': 711, 'max_depth': 7, 'learning_rate': 0.1431209981478018, 'subsample': 0.6550916689808407, 'colsample_bytree': 0.663552628686874, 'gamma': 0.3345393290579163, 'min_child_weight': 5}. Best is trial 18 with value: 0.029757745166550165.
#
# [I 2024-01-23 14:48:43,981] Trial 19 finished with value: 0.028709527137200097 and parameters: {'n_estimators': 727, 'max_depth': 7, 'learning_rate': 0.1590203722654177, 'subsample': 0.6576069533997743, 'colsample_bytree': 0.6309451309023837, 'gamma': 0.3658344081160648, 'min_child_weight': 5}. Best is trial 19 with value: 0.028709527137200097.
#
# [I 2024-01-23 14:48:45,159] Trial 20 finished with value: 0.028360121127416704 and parameters: {'n_estimators': 681, 'max_depth': 7, 'learning_rate': 0.22646555777493493, 'subsample': 0.7939359801606385, 'colsample_bytree': 0.5029255424941903, 'gamma': 0.2520575735950708, 'min_child_weight': 5}. Best is trial 20 with value: 0.028360121127416704.
#
# [I 2024-01-23 14:48:46,286] Trial 21 finished with value: 0.027078965758211004 and parameters: {'n_estimators': 664, 'max_depth': 7, 'learning_rate': 0.22276313730416333, 'subsample': 0.78901643858691, 'colsample_bytree': 0.5357903858210483, 'gamma': 0.28046861437245946, 'min_child_weight': 5}. Best is trial 21 with value: 0.027078965758211004.
#
# [I 2024-01-23 14:48:47,361] Trial 22 finished with value: 0.029641276496622404 and parameters: {'n_estimators': 642, 'max_depth': 6, 'learning_rate': 0.23494941951964846, 'subsample': 0.7960330840019207, 'colsample_bytree': 0.5049170951513041, 'gamma': 0.23707017433235542, 'min_child_weight': 4}. Best is trial 21 with value: 0.027078965758211004.
#
# [I 2024-01-23 14:48:48,398] Trial 23 finished with value: 0.02766130910785003 and parameters: {'n_estimators': 460, 'max_depth': 9, 'learning_rate': 0.22343957719359353, 'subsample': 0.7913911064738535, 'colsample_bytree': 0.5584686036486879, 'gamma': 0.21016051641401629, 'min_child_weight': 4}. Best is trial 21 with value: 0.027078965758211004.
#
# [I 2024-01-23 14:48:49,389] Trial 24 finished with value: 0.028476589797344465 and parameters: {'n_estimators': 449, 'max_depth': 9, 'learning_rate': 0.23850963717771617, 'subsample': 0.8022595499226297, 'colsample_bytree': 0.5421714989399405, 'gamma': 0.24312143367473094, 'min_child_weight': 4}. Best is trial 21 with value: 0.027078965758211004.
#
# [I 2024-01-23 14:48:50,361] Trial 25 finished with value: 0.026904262753319363 and parameters: {'n_estimators': 339, 'max_depth': 9, 'learning_rate': 0.20407473312946528, 'subsample': 0.9180890620290931, 'colsample_bytree': 0.6072590359717219, 'gamma': 0.17062061405482415, 'min_child_weight': 4}. Best is trial 25 with value: 0.026904262753319363.
#
# [I 2024-01-23 14:48:51,193] Trial 26 finished with value: 0.026846028418355483 and parameters: {'n_estimators': 307, 'max_depth': 9, 'learning_rate': 0.20456242350691053, 'subsample': 0.9748631104335498, 'colsample_bytree': 0.6133797737828236, 'gamma': 0.15125172442574805, 'min_child_weight': 2}. Best is trial 26 with value: 0.026846028418355483.
#
# [I 2024-01-23 14:48:52,115] Trial 27 finished with value: 0.02643838807360821 and parameters: {'n_estimators': 297, 'max_depth': 10, 'learning_rate': 0.19018558727585988, 'subsample': 0.9972406746091631, 'colsample_bytree': 0.617605984929682, 'gamma': 0.1264906583702251, 'min_child_weight': 2}. Best is trial 27 with value: 0.02643838807360821.
#
# [I 2024-01-23 14:48:53,063] Trial 28 finished with value: 0.02643838807360821 and parameters: {'n_estimators': 318, 'max_depth': 10, 'learning_rate': 0.19241270882256756, 'subsample': 0.9942179175330321, 'colsample_bytree': 0.6140015220045362, 'gamma': 0.11210027594018912, 'min_child_weight': 2}. Best is trial 27 with value: 0.02643838807360821.
#
# [I 2024-01-23 14:48:54,104] Trial 29 finished with value: 0.025914279058933176 and parameters: {'n_estimators': 246, 'max_depth': 10, 'learning_rate': 0.17945101268853889, 'subsample': 0.9984737103537217, 'colsample_bytree': 0.7022771042043789, 'gamma': 0.011373378716864724, 'min_child_weight': 2}. Best is trial 29 with value: 0.025914279058933176.
#
# [I 2024-01-23 14:48:54,774] Trial 30 finished with value: 0.0302818541812252 and parameters: {'n_estimators': 108, 'max_depth': 10, 'learning_rate': 0.1820135232476503, 'subsample': 0.9408943427363383, 'colsample_bytree': 0.7263359679951448, 'gamma': 0.07790765460128875, 'min_child_weight': 2}. Best is trial 29 with value: 0.025914279058933176.
#
# [I 2024-01-23 14:48:55,851] Trial 31 finished with value: 0.025972513393897056 and parameters: {'n_estimators': 263, 'max_depth': 10, 'learning_rate': 0.179561407141289, 'subsample': 0.9959179484187136, 'colsample_bytree': 0.7063014994799425, 'gamma': 0.0024978405061288206, 'min_child_weight': 2}. Best is trial 29 with value: 0.025914279058933176.
#
# [I 2024-01-23 14:48:56,900] Trial 32 finished with value: 0.025564873049149783 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.1815425349384798, 'subsample': 0.9993863799641617, 'colsample_bytree': 0.7136546587378503, 'gamma': 0.00642661345351316, 'min_child_weight': 1}. Best is trial 32 with value: 0.025564873049149783.
#
# [I 2024-01-23 14:48:57,978] Trial 33 finished with value: 0.025448404379222023 and parameters: {'n_estimators': 204, 'max_depth': 10, 'learning_rate': 0.1744670190332332, 'subsample': 0.9513133643962626, 'colsample_bytree': 0.788730540335496, 'gamma': 0.0020663981461921076, 'min_child_weight': 1}. Best is trial 33 with value: 0.025448404379222023.
#
# [I 2024-01-23 14:48:59,019] Trial 34 finished with value: 0.026846028418355483 and parameters: {'n_estimators': 187, 'max_depth': 10, 'learning_rate': 0.16615793494021866, 'subsample': 0.9462401021353478, 'colsample_bytree': 0.7890232357524972, 'gamma': 7.82196144673143e-05, 'min_child_weight': 1}. Best is trial 33 with value: 0.025448404379222023.
#
# [I 2024-01-23 14:48:59,934] Trial 35 finished with value: 0.027078965758211004 and parameters: {'n_estimators': 218, 'max_depth': 9, 'learning_rate': 0.17471195559348326, 'subsample': 0.8998672607495266, 'colsample_bytree': 0.7095502107282868, 'gamma': 0.05653783167449178, 'min_child_weight': 1}. Best is trial 33 with value: 0.025448404379222023.
#
# [I 2024-01-23 14:49:00,626] Trial 36 finished with value: 0.026962497088283244 and parameters: {'n_estimators': 172, 'max_depth': 10, 'learning_rate': 0.2985325853925143, 'subsample': 0.8675856515949001, 'colsample_bytree': 0.7725391882509299, 'gamma': 0.020370860619895466, 'min_child_weight': 3}. Best is trial 33 with value: 0.025448404379222023.
#
# [I 2024-01-23 14:49:02,006] Trial 37 finished with value: 0.02626368506871657 and parameters: {'n_estimators': 379, 'max_depth': 9, 'learning_rate': 0.13833966715455503, 'subsample': 0.9543682723444148, 'colsample_bytree': 0.8111556912831854, 'gamma': 0.07453374930288251, 'min_child_weight': 1}. Best is trial 33 with value: 0.025448404379222023.
#
# [I 2024-01-23 14:49:02,734] Trial 38 finished with value: 0.02661309107849985 and parameters: {'n_estimators': 216, 'max_depth': 10, 'learning_rate': 0.25606809088829624, 'subsample': 0.9653361194621833, 'colsample_bytree': 0.7601830759902547, 'gamma': 0.17989294321971466, 'min_child_weight': 2}. Best is trial 33 with value: 0.025448404379222023.
#
# [I 2024-01-23 14:49:03,708] Trial 39 finished with value: 0.03179594689028653 and parameters: {'n_estimators': 260, 'max_depth': 9, 'learning_rate': 0.09499689641694692, 'subsample': 0.9214377191792054, 'colsample_bytree': 0.7137999749522936, 'gamma': 0.011559367566311695, 'min_child_weight': 3}. Best is trial 33 with value: 0.025448404379222023.
#
# [I 2024-01-23 14:49:03,963] Trial 40 finished with value: 0.08554623806196138 and parameters: {'n_estimators': 147, 'max_depth': 4, 'learning_rate': 0.1721956014142305, 'subsample': 0.8538593899657234, 'colsample_bytree': 0.8640685608401265, 'gamma': 0.08248254763893627, 'min_child_weight': 1}. Best is trial 33 with value: 0.025448404379222023.
#
# [I 2024-01-23 14:49:05,518] Trial 41 finished with value: 0.024574889354763596 and parameters: {'n_estimators': 383, 'max_depth': 10, 'learning_rate': 0.13329390038265096, 'subsample': 0.9611653315038907, 'colsample_bytree': 0.8049800718471586, 'gamma': 0.07879750265672568, 'min_child_weight': 1}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:06,633] Trial 42 finished with value: 0.02766130910785003 and parameters: {'n_estimators': 266, 'max_depth': 10, 'learning_rate': 0.13305450457502108, 'subsample': 0.9991841523479964, 'colsample_bytree': 0.7447025892190156, 'gamma': 0.10941158344577859, 'min_child_weight': 2}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:08,188] Trial 43 finished with value: 0.024691358024691357 and parameters: {'n_estimators': 381, 'max_depth': 10, 'learning_rate': 0.14898773575994215, 'subsample': 0.9739683216696093, 'colsample_bytree': 0.8092299273597225, 'gamma': 0.04535163368148227, 'min_child_weight': 1}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:09,605] Trial 44 finished with value: 0.024691358024691357 and parameters: {'n_estimators': 386, 'max_depth': 9, 'learning_rate': 0.1460346433254467, 'subsample': 0.8903898690895181, 'colsample_bytree': 0.8043656132660336, 'gamma': 0.05520031960428059, 'min_child_weight': 1}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:11,239] Trial 45 finished with value: 0.025390170044258142 and parameters: {'n_estimators': 516, 'max_depth': 9, 'learning_rate': 0.14932008594691146, 'subsample': 0.8972012160918511, 'colsample_bytree': 0.7977569139887816, 'gamma': 0.07202712567867253, 'min_child_weight': 1}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:12,552] Trial 46 finished with value: 0.026962497088283244 and parameters: {'n_estimators': 510, 'max_depth': 9, 'learning_rate': 0.14828316194929697, 'subsample': 0.895073861812516, 'colsample_bytree': 0.8057520335845529, 'gamma': 0.18195390227007027, 'min_child_weight': 1}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:13,915] Trial 47 finished with value: 0.030048916841369677 and parameters: {'n_estimators': 516, 'max_depth': 8, 'learning_rate': 0.09226642586072768, 'subsample': 0.8353718999094631, 'colsample_bytree': 0.8442026535143199, 'gamma': 0.0628928634971031, 'min_child_weight': 3}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:15,576] Trial 48 finished with value: 0.030107151176333558 and parameters: {'n_estimators': 386, 'max_depth': 9, 'learning_rate': 0.06368178294933732, 'subsample': 0.926844318356704, 'colsample_bytree': 0.8949312325948394, 'gamma': 0.1505516579774996, 'min_child_weight': 1}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:16,927] Trial 49 finished with value: 0.028884230142091738 and parameters: {'n_estimators': 591, 'max_depth': 8, 'learning_rate': 0.10449006085716805, 'subsample': 0.8871761420239457, 'colsample_bytree': 0.7926005597739239, 'gamma': 0.2928924057137186, 'min_child_weight': 1}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:18,173] Trial 50 finished with value: 0.028127183787561183 and parameters: {'n_estimators': 396, 'max_depth': 9, 'learning_rate': 0.12567963062277088, 'subsample': 0.9688974451949907, 'colsample_bytree': 0.834968594738783, 'gamma': 0.1169618179017075, 'min_child_weight': 3}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:19,592] Trial 51 finished with value: 0.025739576054041424 and parameters: {'n_estimators': 357, 'max_depth': 10, 'learning_rate': 0.15613606868418037, 'subsample': 0.9200591245183052, 'colsample_bytree': 0.8683984208375427, 'gamma': 0.0879279351211476, 'min_child_weight': 1}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:21,444] Trial 52 finished with value: 0.024866061029582998 and parameters: {'n_estimators': 483, 'max_depth': 10, 'learning_rate': 0.1349724315717632, 'subsample': 0.9421309450527665, 'colsample_bytree': 0.8206048600198718, 'gamma': 0.04291947900131625, 'min_child_weight': 1}. Best is trial 41 with value: 0.024574889354763596.
#
# [I 2024-01-23 14:49:23,248] Trial 53 finished with value: 0.024400186349871844 and parameters: {'n_estimators': 486, 'max_depth': 10, 'learning_rate': 0.1335183140294354, 'subsample': 0.9454811856697352, 'colsample_bytree': 0.815861412596294, 'gamma': 0.05182181770082431, 'min_child_weight': 1}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:24,564] Trial 54 finished with value: 0.028825995807127858 and parameters: {'n_estimators': 491, 'max_depth': 9, 'learning_rate': 0.13403860644217752, 'subsample': 0.9036844864069898, 'colsample_bytree': 0.820053220220979, 'gamma': 0.044450242746799526, 'min_child_weight': 7}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:25,551] Trial 55 finished with value: 0.03336827393431163 and parameters: {'n_estimators': 558, 'max_depth': 10, 'learning_rate': 0.11818683152875759, 'subsample': 0.8601323926165939, 'colsample_bytree': 0.9504065477695495, 'gamma': 0.9783961058076128, 'min_child_weight': 2}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:26,054] Trial 56 finished with value: 0.1010948054973212 and parameters: {'n_estimators': 418, 'max_depth': 3, 'learning_rate': 0.07293679846934972, 'subsample': 0.9377271539498836, 'colsample_bytree': 0.8651823845935762, 'gamma': 0.20977011133979087, 'min_child_weight': 1}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:26,961] Trial 57 finished with value: 0.03034008851618919 and parameters: {'n_estimators': 481, 'max_depth': 9, 'learning_rate': 0.1429882995905099, 'subsample': 0.9756241158195132, 'colsample_bytree': 0.7640774598260562, 'gamma': 0.4450346990179075, 'min_child_weight': 2}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:27,560] Trial 58 finished with value: 0.06720242254833453 and parameters: {'n_estimators': 442, 'max_depth': 4, 'learning_rate': 0.1098582545660547, 'subsample': 0.8787186045214184, 'colsample_bytree': 0.8985487035151312, 'gamma': 0.05900777542319282, 'min_child_weight': 1}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:28,590] Trial 59 finished with value: 0.03034008851618919 and parameters: {'n_estimators': 529, 'max_depth': 8, 'learning_rate': 0.1261848765166804, 'subsample': 0.7613081125216627, 'colsample_bytree': 0.8300725454088587, 'gamma': 0.6317150003509359, 'min_child_weight': 1}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:31,998] Trial 60 finished with value: 0.037502911716748244 and parameters: {'n_estimators': 592, 'max_depth': 10, 'learning_rate': 0.017197481189867914, 'subsample': 0.8376251640887671, 'colsample_bytree': 0.7357524475515203, 'gamma': 0.8480434803650333, 'min_child_weight': 2}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:33,578] Trial 61 finished with value: 0.024691358024691357 and parameters: {'n_estimators': 425, 'max_depth': 10, 'learning_rate': 0.16632862451573105, 'subsample': 0.9549125535510788, 'colsample_bytree': 0.799746461155532, 'gamma': 0.04767574088278558, 'min_child_weight': 1}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:34,884] Trial 62 finished with value: 0.026030747728860937 and parameters: {'n_estimators': 414, 'max_depth': 10, 'learning_rate': 0.15060900854659057, 'subsample': 0.9606403040422524, 'colsample_bytree': 0.8060629758020175, 'gamma': 0.14280541223207555, 'min_child_weight': 1}. Best is trial 53 with value: 0.024400186349871844.
#
# [I 2024-01-23 14:49:36,653] Trial 63 finished with value: 0.024225483344980203 and parameters: {'n_estimators': 471, 'max_depth': 10, 'learning_rate': 0.1633025520577759, 'subsample': 0.9350691423606469, 'colsample_bytree': 0.7750337941447298, 'gamma': 0.04208040240599859, 'min_child_weight': 1}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:38,088] Trial 64 finished with value: 0.025564873049149783 and parameters: {'n_estimators': 344, 'max_depth': 10, 'learning_rate': 0.1318213418921744, 'subsample': 0.9337014448278835, 'colsample_bytree': 0.7697421037381929, 'gamma': 0.04310510878995465, 'min_child_weight': 2}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:38,967] Trial 65 finished with value: 0.03162124388539478 and parameters: {'n_estimators': 473, 'max_depth': 10, 'learning_rate': 0.16279030958588908, 'subsample': 0.910767736120434, 'colsample_bytree': 0.8504058973134333, 'gamma': 0.758359768531336, 'min_child_weight': 1}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:40,093] Trial 66 finished with value: 0.026962497088283244 and parameters: {'n_estimators': 424, 'max_depth': 10, 'learning_rate': 0.19471689852819454, 'subsample': 0.9779976403909761, 'colsample_bytree': 0.8195548121658112, 'gamma': 0.11499019395887, 'min_child_weight': 2}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:41,368] Trial 67 finished with value: 0.02533193570929415 and parameters: {'n_estimators': 367, 'max_depth': 9, 'learning_rate': 0.16613397975264765, 'subsample': 0.9526052793113563, 'colsample_bytree': 0.7741517168419592, 'gamma': 0.04477291900511898, 'min_child_weight': 2}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:42,979] Trial 68 finished with value: 0.02655485674353597 and parameters: {'n_estimators': 328, 'max_depth': 10, 'learning_rate': 0.11839426035625554, 'subsample': 0.9434630938907786, 'colsample_bytree': 0.8814084369996136, 'gamma': 0.09906225077490366, 'min_child_weight': 1}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:44,101] Trial 69 finished with value: 0.03167947822035877 and parameters: {'n_estimators': 293, 'max_depth': 10, 'learning_rate': 0.10104592231740506, 'subsample': 0.978699086784979, 'colsample_bytree': 0.7493993039355419, 'gamma': 0.04194596933488742, 'min_child_weight': 7}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:45,190] Trial 70 finished with value: 0.027020731423247124 and parameters: {'n_estimators': 451, 'max_depth': 10, 'learning_rate': 0.21025232641254193, 'subsample': 0.9309369313356096, 'colsample_bytree': 0.9240438343540373, 'gamma': 0.1648471954202587, 'min_child_weight': 3}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:46,612] Trial 71 finished with value: 0.024749592359655237 and parameters: {'n_estimators': 385, 'max_depth': 9, 'learning_rate': 0.16533798828944768, 'subsample': 0.9599428512345315, 'colsample_bytree': 0.7773858911992243, 'gamma': 0.03393613253822682, 'min_child_weight': 1}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:47,932] Trial 72 finished with value: 0.02655485674353597 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.14142719759218825, 'subsample': 0.9599665887772231, 'colsample_bytree': 0.8467943564335199, 'gamma': 0.13282682856777323, 'min_child_weight': 1}. Best is trial 63 with value: 0.024225483344980203.
#
# [I 2024-01-23 14:49:49,648] Trial 73 finished with value: 0.024050780340088562 and parameters: {'n_estimators': 488, 'max_depth': 10, 'learning_rate': 0.1566267039688344, 'subsample': 0.983792959762914, 'colsample_bytree': 0.7808506563815991, 'gamma': 0.03640713895037651, 'min_child_weight': 1}. Best is trial 73 with value: 0.024050780340088562.
#
# [I 2024-01-23 14:49:51,046] Trial 74 finished with value: 0.02638015373864433 and parameters: {'n_estimators': 435, 'max_depth': 10, 'learning_rate': 0.15679330180238688, 'subsample': 0.9836008796769813, 'colsample_bytree': 0.7828528961921727, 'gamma': 0.08601733014866163, 'min_child_weight': 2}. Best is trial 73 with value: 0.024050780340088562.
#
# [I 2024-01-23 14:49:51,844] Trial 75 finished with value: 0.03400885161891454 and parameters: {'n_estimators': 369, 'max_depth': 6, 'learning_rate': 0.16886680514008623, 'subsample': 0.967056714123272, 'colsample_bytree': 0.7539918564342108, 'gamma': 0.19545437349648268, 'min_child_weight': 1}. Best is trial 73 with value: 0.024050780340088562.
#
# [I 2024-01-23 14:49:53,743] Trial 76 finished with value: 0.024866061029582998 and parameters: {'n_estimators': 568, 'max_depth': 9, 'learning_rate': 0.18828727238096177, 'subsample': 0.9126111604790811, 'colsample_bytree': 0.8014181219855244, 'gamma': 0.021038627173801186, 'min_child_weight': 1}. Best is trial 73 with value: 0.024050780340088562.
#
# [I 2024-01-23 14:49:55,155] Trial 77 finished with value: 0.02638015373864433 and parameters: {'n_estimators': 631, 'max_depth': 10, 'learning_rate': 0.15739846460448453, 'subsample': 0.9855149044719833, 'colsample_bytree': 0.786798824913064, 'gamma': 0.09947044505744322, 'min_child_weight': 2}. Best is trial 73 with value: 0.024050780340088562.
#
# [I 2024-01-23 14:49:56,306] Trial 78 finished with value: 0.02661309107849985 and parameters: {'n_estimators': 404, 'max_depth': 9, 'learning_rate': 0.2122423459381092, 'subsample': 0.7012803442287733, 'colsample_bytree': 0.7381200141572678, 'gamma': 0.13125963581443395, 'min_child_weight': 6}. Best is trial 73 with value: 0.024050780340088562.
#
# [I 2024-01-23 14:49:58,349] Trial 79 finished with value: 0.024516655019799716 and parameters: {'n_estimators': 542, 'max_depth': 10, 'learning_rate': 0.14089603695581335, 'subsample': 0.9507823008908688, 'colsample_bytree': 0.7765404174690219, 'gamma': 0.031440250652767385, 'min_child_weight': 1}. Best is trial 73 with value: 0.024050780340088562.
#
# [I 2024-01-23 14:49:59,620] Trial 80 finished with value: 0.027020731423247124 and parameters: {'n_estimators': 545, 'max_depth': 10, 'learning_rate': 0.14642214236090548, 'subsample': 0.8802565033371804, 'colsample_bytree': 0.8308601805646567, 'gamma': 0.278378239735325, 'min_child_weight': 2}. Best is trial 73 with value: 0.024050780340088562.
#
# [I 2024-01-23 14:50:01,450] Trial 81 finished with value: 0.022711390635918982 and parameters: {'n_estimators': 502, 'max_depth': 10, 'learning_rate': 0.1625674503332272, 'subsample': 0.9555822470882451, 'colsample_bytree': 0.7724584042631472, 'gamma': 0.034378098319732785, 'min_child_weight': 1}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:03,184] Trial 82 finished with value: 0.02393431167016069 and parameters: {'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.152983003983914, 'subsample': 0.9289694585959812, 'colsample_bytree': 0.8100822504082427, 'gamma': 0.07044443622964315, 'min_child_weight': 1}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:05,088] Trial 83 finished with value: 0.025564873049149783 and parameters: {'n_estimators': 499, 'max_depth': 10, 'learning_rate': 0.12400001142836656, 'subsample': 0.9330048578294321, 'colsample_bytree': 0.8116174177410057, 'gamma': 0.07442401424340711, 'min_child_weight': 1}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:06,949] Trial 84 finished with value: 0.02498252969951087 and parameters: {'n_estimators': 612, 'max_depth': 10, 'learning_rate': 0.1407061049636318, 'subsample': 0.9109343997113226, 'colsample_bytree': 0.7599953184040391, 'gamma': 0.0998950659698542, 'min_child_weight': 1}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:08,839] Trial 85 finished with value: 0.024341952014907964 and parameters: {'n_estimators': 461, 'max_depth': 10, 'learning_rate': 0.15138234099303627, 'subsample': 0.9877072816507637, 'colsample_bytree': 0.8396937050802744, 'gamma': 0.0011340749796489788, 'min_child_weight': 1}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:10,710] Trial 86 finished with value: 0.024749592359655237 and parameters: {'n_estimators': 537, 'max_depth': 10, 'learning_rate': 0.15235551079268983, 'subsample': 0.9872383648350527, 'colsample_bytree': 0.7272842558698575, 'gamma': 0.021140932444744395, 'min_child_weight': 2}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:12,080] Trial 87 finished with value: 0.028243652457488944 and parameters: {'n_estimators': 461, 'max_depth': 10, 'learning_rate': 0.1755053088381134, 'subsample': 0.9661611761613346, 'colsample_bytree': 0.8414781120864795, 'gamma': 0.0017466463732887087, 'min_child_weight': 9}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:13,780] Trial 88 finished with value: 0.025564873049149783 and parameters: {'n_estimators': 468, 'max_depth': 10, 'learning_rate': 0.11460684563025235, 'subsample': 0.9857308985822658, 'colsample_bytree': 0.8599603456540634, 'gamma': 0.07071728551247755, 'min_child_weight': 2}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:14,651] Trial 89 finished with value: 0.0408222688096902 and parameters: {'n_estimators': 499, 'max_depth': 5, 'learning_rate': 0.1292912798589649, 'subsample': 0.9473243197991408, 'colsample_bytree': 0.7816480604657767, 'gamma': 0.14763116640287716, 'min_child_weight': 1}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:16,628] Trial 90 finished with value: 0.024109014675052443 and parameters: {'n_estimators': 576, 'max_depth': 10, 'learning_rate': 0.15888358974608086, 'subsample': 0.6312837518306418, 'colsample_bytree': 0.6892446384676428, 'gamma': 0.026118416931019545, 'min_child_weight': 2}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:18,734] Trial 91 finished with value: 0.023351968320521777 and parameters: {'n_estimators': 575, 'max_depth': 10, 'learning_rate': 0.1595741500896193, 'subsample': 0.6169811239465041, 'colsample_bytree': 0.6423177074263348, 'gamma': 0.029522334634615288, 'min_child_weight': 1}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:20,821] Trial 92 finished with value: 0.023002562310738384 and parameters: {'n_estimators': 571, 'max_depth': 10, 'learning_rate': 0.1571177363113564, 'subsample': 0.6161284935925518, 'colsample_bytree': 0.6368707153349937, 'gamma': 0.025847629895924196, 'min_child_weight': 1}. Best is trial 81 with value: 0.022711390635918982.
#
# [I 2024-01-23 14:50:22,791] Trial 93 finished with value: 0.02247845329606335 and parameters: {'n_estimators': 574, 'max_depth': 10, 'learning_rate': 0.19595572887858625, 'subsample': 0.6267859301420361, 'colsample_bytree': 0.6330030860183017, 'gamma': 0.029196708609215798, 'min_child_weight': 1}. Best is trial 93 with value: 0.02247845329606335.
#
# [I 2024-01-23 14:50:24,818] Trial 94 finished with value: 0.023351968320521777 and parameters: {'n_estimators': 578, 'max_depth': 10, 'learning_rate': 0.18496234009794416, 'subsample': 0.6274361498907034, 'colsample_bytree': 0.6366901119326895, 'gamma': 0.018307227459858688, 'min_child_weight': 1}. Best is trial 93 with value: 0.02247845329606335.
#
# [I 2024-01-23 14:50:26,723] Trial 95 finished with value: 0.02533193570929415 and parameters: {'n_estimators': 578, 'max_depth': 10, 'learning_rate': 0.18310696438491963, 'subsample': 0.6289376188227618, 'colsample_bytree': 0.6506299714467693, 'gamma': 0.023687674449977256, 'min_child_weight': 2}. Best is trial 93 with value: 0.02247845329606335.
#
# [I 2024-01-23 14:50:28,953] Trial 96 finished with value: 0.02242021896109947 and parameters: {'n_estimators': 633, 'max_depth': 10, 'learning_rate': 0.17303403699591946, 'subsample': 0.5840735105489874, 'colsample_bytree': 0.633675401703348, 'gamma': 0.004710773308855984, 'min_child_weight': 1}. Best is trial 96 with value: 0.02242021896109947.
#
# [I 2024-01-23 14:50:30,926] Trial 97 finished with value: 0.024109014675052443 and parameters: {'n_estimators': 641, 'max_depth': 10, 'learning_rate': 0.19654725035508144, 'subsample': 0.5752211226994047, 'colsample_bytree': 0.5888262428180455, 'gamma': 0.02534693218641023, 'min_child_weight': 2}. Best is trial 96 with value: 0.02242021896109947.
#
# [I 2024-01-23 14:50:32,852] Trial 98 finished with value: 0.02492429536454699 and parameters: {'n_estimators': 671, 'max_depth': 10, 'learning_rate': 0.19268902754122058, 'subsample': 0.5735896525546589, 'colsample_bytree': 0.5930210220776102, 'gamma': 0.023566653898045353, 'min_child_weight': 3}. Best is trial 96 with value: 0.02242021896109947.
#
# [I 2024-01-23 14:50:34,579] Trial 99 finished with value: 0.024633123689727476 and parameters: {'n_estimators': 633, 'max_depth': 9, 'learning_rate': 0.20108099066113372, 'subsample': 0.6049522798468471, 'colsample_bytree': 0.6359652263000455, 'gamma': 0.09468957679567264, 'min_child_weight': 2}. Best is trial 96 with value: 0.02242021896109947.
# {'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 0}

# %%
best_model_xgb = xgb.XGBClassifier(**best_params)
best_model_xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_features=1,
#               max_leaves=None, min_child_weight=None, min_samples_leaf=1,
#               min_samples_split=2, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, ...)

# %% [markdown]
# ### Printing the accuracy,recall,precision,f1 scores for models:

# %%
models = [model_dtc, model_knn, model_lr, model_rfc, model_gb, model_xgb, model_voting, model_stacking, best_model_rfc, best_model_xgb]
model_names = ["Decision Tree","KNN","Logistic_regression","Random Forest", "GB", "XGB", "Voting", "Stacking", "Optimized Random Forest", "Optimized XGB"]

# %%
# Initialize empty lists to store scores
accuracy_scores, recall_scores, precision_scores, f1_scores = [], [], [], []

# Calculate and store scores for each model
for model in models:
    accuracy, recall, precision, f1 = predict_scores(model, X_test, y_test)
    accuracy_scores.append(accuracy)
    recall_scores.append(recall)
    precision_scores.append(precision)
    f1_scores.append(f1)

# Create a DataFrame using the scores and model names
scores_df = pd.DataFrame({
    "Model": model_names,
    "Accuracy": accuracy_scores,
    "Recall": recall_scores,
    "Precision": precision_scores,
    "F1 Score": f1_scores
})

# %%
scores_df
# Out:
#                      Model  Accuracy    Recall  Precision  F1 Score
# 0            Decision Tree  0.970359  1.000000   0.944244  0.971322
# 1                      KNN  0.936641  0.998376   0.889050  0.940546
# 2      Logistic_regression  0.845155  0.867749   0.831203  0.849083
# 3            Random Forest  0.980783  1.000000   0.963128  0.981218
# 4                       GB  0.877941  0.921578   0.848355  0.883452
# 5                      XGB  0.952830  0.996404   0.916845  0.954970
# 6                   Voting  0.958828  1.000000   0.924199  0.960606
# 7                 Stacking  0.997729  1.000000   0.995496  0.997743
# 8  Optimized Random Forest  0.987654  1.000000   0.975996  0.987852
# 9            Optimized XGB  0.952830  0.996404   0.916845  0.954970

# %%
selected_models = [model_stacking, best_model_rfc, best_model_xgb]
selected_model_names = ["Stacking", "Optimized Random Forest", "Optimized XGB"]

# %% [markdown]
# ## Visualizing the Confusion Matrix

# %%
plot_confusion_matrices(X_test=X_test, y_test=y_test, models=selected_models, model_names=selected_model_names)

# %% [markdown]
# ## Visualizing the ROC curve with AUC values

# %%
draw_AUC_graph(X_train, X_test, y_train, y_test, models=selected_models, model_names=selected_model_names)
# Out:
# Stacking - Train AUC: 0.9999
#
# Stacking - Test AUC: 0.9998
#
# Optimized Random Forest - Train AUC: 1.0000
#
# Optimized Random Forest - Test AUC: 0.9999
#
# Optimized XGB - Train AUC: 0.9979
#
# Optimized XGB - Test AUC: 0.9852

# %% [markdown]
# ## Visualizing the bias,variance tradeoff and train,test,cross-validation scores

# %%
visualize_fitting_scores(models=selected_models, model_names=selected_model_names, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

# %%
bias_variance(model_knn,X_train,y_train)
